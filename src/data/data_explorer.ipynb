# %%
import pandas as pd
import json

# %%
x=json.load(open('/Users/ahura/Nexus/TWMC/data/repos.json'))

# %%
type(x)
# Out:
# dict

# %%
x
# Out:
# {'VaderCoinProject/vadercoin': 238,
#  'mariusgheorghies/python': 3083,
#  'flynncowell/dalekbot-1': 62,
#  'wjones30309/MachineLearningSamples-Notebooks': 10,
#  'HumanCellAtlas/ingest-common': 69,
#  'NJUPole/mars': 1096,
#  'mberaha/semihdp-scripts': 1,
#  'Interactions-HSG/2022-CNDS-Public': 3,
#  'chuy98JS/Curso-Python-Intermedio': 7,
#  'Chraser/inlay': 2,
#  'bglobal/origin': 15,
#  'kblaszczak-intel/open_model_zoo': 71,
#  'souravsingh/chainercv': 348,
#  'sgibson91/bump-jhub-image-action': 13,
#  'ace19-dev/CBNetV2': 22,
#  'sublee/hangulize': 85,
#  'hroncok/python-dingz': 8,
#  'escer/django-multivaluefield': 10,
#  'VForWaTer/uncertainty-framework': 9,
#  'Kiran1178/Python201901': 11,
#  'katyakats/mlrun': 164,
#  'saanobhaai/apman': 29,
#  'selimmh/Python_Basics': 62,
#  'anderskate/recipe-app-api': 18,
#  'dylannalex/electripy': 10,
#  'sainazuoan1/google-research': 1089,
#  'silentsokolov/dagster': 1208,
#  'everestmz/l2tdevtools': 104,
#  'BaiYuYuan/FNA': 54,
#  'CMPUT414W15/LEAP': 7,
#  'ljdawn/asa_code': 30,
#  'lsgrep/jina': 77,
#  'cschloer/pudl': 97,
#  'joao-frohlich/covid-sc': 23,
#  'jdeaton/spack': 3370,
#  'JohnStarich/dotfiles': 14,
#  'mikomel/scattering-compositional-learner': 4,
#  'Manifold-Computing/MMAML-Classification': 33,
#  'shubhamjain0594/opalalgorithms': 16,
#  'learnerzhang/AnalyticsVidhya': 46,
#  'DaDaMrX/ReaLiSe': 120,
#  'Manny27nyc/insights-core': 13,
#  'jakublipinski/tensorflow': 7,
#  'mittalkartik2000/lbry-sdk': 6,
#  'Sravanksk/qbo-db-connector': 11,
#  'NeCTAR-RC/reporting-api': 13,
#  'benharmonics/chime': 1,
#  'gunhoon/sunnyvale': 1,
#  'synapticarbors/sk-dist': 44,
#  'nickxla/arp-cache-poisoning': 174,
#  'OrginalS/back-end': 65,
#  'handle/flask_maple': 28,
#  'qingen/PaddleSpeech': 302,
#  'glorialulu/tsnet': 37,
#  'CreekLou/DeepCTR': 93,
#  'mreso/torchrec': 89,
#  'mostafa-arshadi/aiotdlib': 795,
#  'DougMahoney/metatools': 74,
#  'mhadiahmed/ecommerce-with-django2-tutorial': 28,
#  'sikler/cmssw': 12280,
#  'LarryZetzl/boring_lz': 61,
#  'S-Thaler/SITE': 10,
#  'Chunfang/defmod-swpc': 32,
#  'yuto-moriizumi/AtCoder': 1643,
#  'yycc179/urlp': 805,
#  'generalui/Qcodes-1': 106,
#  'wardrobe-auth/wardrobe': 33,
#  'ShaneHarvey/pytype': 9,
#  'xswz8015/infra': 855,
#  'TermiNutZ/pills_online': 22,
#  'halton/chromium-crosswalk': 302,
#  'avkvl/salt': 365,
#  'jmugz3/euler': 10,
#  'rysdyk/avocado': 81,
#  'crash-bandic00t/geekshop': 42,
#  'agilentia/sentry-app': 402,
#  'Eronarn/dagster': 310,
#  'JarnoRFB/xarray': 17,
#  'theCapypara/riptide-engine-docker': 12,
#  'cloudbau/cinder': 92,
#  'belerico/py-asciimath': 26,
#  'sheffgeeks/burritobot': 17,
#  'RenjieW/SketchDLC': 549,
#  'BharadwajEdera/scikit-learn': 718,
#  'nochiel/CypherpunkPay': 10,
#  'shmillo/SimplePythonExamples': 50,
#  'bogdanstate/pyprob': 91,
#  'dendron2000/Thespian': 133,
#  'rprimet/icubam': 40,
#  'AIasd/leaderboard': 26,
#  'zsoltn/python-otc-lambda': 4,
#  'sinteur/Internet.nl': 53,
#  'amodas/PRIME-augmentations': 23,
#  'wdr123/DARP-SBIR': 59,
#  'TTOFFLINE-LEAK/ttoffline': 3322,
#  'manopapad/legate.numpy': 238,
#  'GitHubToMaster/Python-Learn': 40,
#  'hareeshbabu82ns/smart-sanskrit-annotator': 29,
#  'victoriaakelly/srndna-master': 22,
#  'onceawaken/MKL-DNN_Eigen_Boost_OpenMPI_GoogleTests_Examples': 2349,
#  'snappyflow/sftrace-python-agent': 20,
#  'rrhuffy/hybristools': 24,
#  'karl-sc/cg-list-site-policy-csv': 1,
#  'hchandra/chef-repo': 3,
#  'taofei-pro/psd-tools': 81,
#  'JamesMutahi/Netflix-Clone': 9,
#  'HCSolomon/Hidden-Gems': 7,
#  'shirtsgroup/analyze_foldamers': 36,
#  'agrexgh/meson': 95,
#  'bonifak/raven': 124,
#  'Smarker/Vera': 11,
#  '5laps2go/xbrr': 44,
#  'Xiraaa/tvm': 41,
#  'jinmang2/boostcamp_ai_tech_2': 6,
#  'cafltar/CafECTowerMeteorology_AzureDataLakeMetToGeoEventServer': 8,
#  'sesam-community/Sesam-Deployer': 5,
#  'bjb421361141/demoProject': 16,
#  'qubixes/parcels': 3,
#  'pylangstudy/201709': 273,
#  'pearsontechnology/st2contrib': 104,
#  'dragonbone81/bobcat-courses-backend': 60,
#  'eduDorus/pytorch-forecasting': 35,
#  'RobinD42/yt-dlc': 39,
#  'lucymli/pyro': 78,
#  'Batalex/pandas': 483,
#  'nmichlo/mtg-ml': 28,
#  'Kayuii/trezor-crypto': 691,
#  'spectralDNS/shenfun': 111,
#  'dungpham98/HiDDeN': 29,
#  'jhunkeler/webbpsf': 13,
#  'faezs/tensor2tensor': 40,
#  'Ciuel/Proyecto-Django': 13,
#  'eura17/crypto-bot': 9,
#  'ace-han/saleor_auth': 7,
#  'kkrampa/commcare-hq': 3838,
#  'PfizerRD/pysit2stand': 24,
#  'michael-golden/pulumi-aws': 809,
#  'jsmesami/naovoce': 128,
#  'louiz/poezio': 79,
#  'Anioko/reusable': 89,
#  'aandrien/LMPC': 30,
#  'Westlake-AI/openmixup': 781,
#  'MarcelRobitaille/opentrons': 43,
#  'halton/crosswalk': 6,
#  'gurkslask/hamcwebc': 24,
#  'hhhhuiyuan/apc524_directional_clustering': 24,
#  'AdaptiveBProcess/Simod': 31,
#  'llucid-97/dfa-scales-to-modern-deep-learning': 28,
#  'agconti/njode': 31,
#  'cburkert/pyGitPrivacy': 5,
#  'jolive1993/CalcApp': 1,
#  'EDjur/beam': 478,
#  'vd4mmind/genomics': 24,
#  'MachineLearningBCAM/minimax-risk-classifier': 265,
#  'hbolzan/django-sql-to-rest': 35,
#  'joy91227/rt-utils': 11,
#  'TravisWheelerLab/polyA': 40,
#  'Vanessa-kriby/Python': 233,
#  'taufikxu/FD-ScoreMatching': 96,
#  'Neklaustares-tPtwP/torchflare': 67,
#  'russellgao/algorithm': 201,
#  'EduardoPedrosa/Reversi-Python': 5,
#  'kalisp/pype': 203,
#  'flexo333/realestate-com-au-api': 9,
#  'nick-allen/python-roundhouse': 14,
#  'AntoineD/jep': 9,
#  'AleksaC/django-hordak': 69,
#  'srinivas32/magic-wormhole-mailbox-server': 22,
#  'michael-lash/Inverse_Classification': 5,
#  'arenadata/adcm': 260,
#  'gatarelib/PyTorchCV': 110,
#  'gustavo-momente/word2vec_variations': 21,
#  'AleBurzio11/webots_ros2': 26,
#  'CarlosHenrique13/Python': 23,
#  'rgl/lms': 16,
#  'vectranetworks/cloudgoat': 2,
#  'peter-freshworks/lear': 37,
#  'RobWelbourn/Twilio-Studio': 1,
#  'expz/muzero-ray': 33,
#  'searchivarius/metric-learn': 14,
#  'Wuradclan/Pycom': 3,
#  'Artificial-Brain/quantumcat': 43,
#  'Shanshan7/easy_anomaly_detection': 23,
#  'blake-shaffer/avionics': 48,
#  'faskr/OpenRadar': 35,
#  'vanthoi/mogua-blockchain': 309,
#  'zhwycsz/edd': 175,
#  'nbro/probability': 77,
#  'Asap7772/railrl_evalsawyer': 2902,
#  'vladushakov987/appengine_python3': 693,
#  'Jack-Sun-007/pymsfilereader': 9,
#  'brondsem/allura': 439,
#  'jkolokotronis/ds_mod_tools': 898,
#  'aldebaran1/gpstec': 13,
#  'krodyush/nncf': 51,
#  'jeroenvdwaal/home-connect-api': 82,
#  'HeberGB/AI': 5,
#  'jmferrer/awx': 425,
#  'thiagodasilva/runway': 13,
#  'puria/sawtooth-sdk-python': 30,
#  'ralphqq/ph-earthquake-dashboard': 38,
#  'moyogo/spacy': 152,
#  'Rebase-havoc/android_vendor_havoc': 1,
#  'syedshahab698/UnitTesting_In_Python': 2,
#  'ringwraith/zvt': 86,
#  'mborgerson/slimbootloader': 293,
#  'gabm/conda-build': 33,
#  'AhteshamSid/News-Scrapper': 14,
#  'cornell-zhang/GLAIVE': 39,
#  'LoLab-VU/Bayesian_Inference_of_Network_Dynamics': 8811,
#  'jonathanpwolfe/Tests_Demo': 6,
#  'WikiMegrez/wikisearch': 9,
#  'SpamExperts/bitten': 67,
#  'uberr2000/portal20': 3,
#  'gig-tech/libcloud': 520,
#  'Mikowmer/fichub-cli': 7,
#  'pyx/monad': 35,
#  'Techwolfy/yiffcoin': 8,
#  'dtroupe18/Thesis-Survey-Of-Political-Bots-On-Twitter': 12,
#  'sawdog/seafile-docker': 3,
#  'pauleveritt/arcade': 61,
#  'em3ndez/Nuitka': 75,
#  'adnang/pulumi-azure': 641,
#  'pnnsumedh09/CFU-Playground': 135,
#  'honza/greek-reader': 6,
#  'lamby/fluids': 93,
#  'kunlabora/Agile_Data_Code_2': 83,
#  'mohdbakhrayba/ledger': 454,
#  'theerapolMan/openteam': 1,
#  'dangra/scrapy-sci': 19,
#  'ZeitOnline/zeit.find': 11,
#  'gabbork/django': 104,
#  'grimmlab/easyPheno': 37,
#  'mohitshah3111999/sympy': 2,
#  'Gelbpunkt/discord.py': 7,
#  'jberstler/core': 200,
#  'brandonmbare/csbuild': 39,
#  'bopopescu/nova-token': 1407,
#  'arthurh4/rancher': 4,
#  'deedos/fermentrack': 8,
#  'fhqjgd/python2.7': 480,
#  'liaojiacan/dyanmic-host': 21,
#  'hemingchen/RoboND-Perception-Exercises': 4,
#  'qianyunzz/mne': 243,
#  'trflorian/bleak': 20,
#  'josiah-wolf-oberholtzer/supriya': 105,
#  'Myst1c-a/phen-cogs': 102,
#  'gorgeousbubble/Nightmare': 108,
#  'sequence-dev/sequence': 30,
#  'gdaguilarc/OpenXC-Data-Grabber-Monitor': 2,
#  'shubham-shahh/fprime': 114,
#  'liusc27/aliyun-openapi-python-sdk': 564,
#  'app-generator/api-server-django-sample': 11,
#  'CyberUserBot/CyberInstaller': 5,
#  'rocksnow1942/microblog': 16,
#  'civicstudio/bitcoin-sv': 150,
#  'sisodiya2421/greenEarth': 2,
#  'State-xyz/pyoidc': 761,
#  'ssbc/ssb-spec-drafts': 28,
#  'skydownacai/AIOCA': 7,
#  'op8867555/BGmi': 32,
#  'digirati-co-uk/cupcake': 9,
#  'Nuolong/bobbit': 77,
#  'matteosox/nba': 26,
#  'Tiarles/Statistical-Wavelet-Filtering': 8,
#  'RubenPX/django-orchestra': 271,
#  'parksey/-': 40,
#  'mattytrentini/micropython-stubs': 2294,
#  'lichangao1826/rpc-service': 22,
#  'DiamondLightSource/python-murfey': 28,
#  'dolik-rce/skein': 14,
#  'DDMGNI/viVorticity2D': 18,
#  'zmmwl/FATE': 69,
#  'QuocAnh90/Uintah_Aalto': 79,
#  'arkhn/cleaning-scripts': 43,
#  'mthipparthi/dj-currencies': 18,
#  'saurabhsuryawanshi/ecommerce': 115,
#  'archman/unicorn-webapp': 17,
#  'maik97/wacky-rl': 41,
#  'wtomalves/exerciciopython': 149,
#  'diazandr3s/MONAILabel-Apps': 9,
#  'hanksudo/github-stars': 2,
#  'kristianeschenburg/parcellearning': 47,
#  'DavidLBick/espnet-1': 62,
#  'papkov/pytorch-toolbelt': 69,
#  'fochoao/cpython': 1808,
#  'diegogarciapablo/prototipo': 40,
#  'cerevo/-listnr-server-sample-py': 7,
#  'h4ck3rm1k3/pythoscope': 141,
#  'jkznst/detectron2': 31,
#  'John-Keating/DengueAI': 1,
#  'JaneTurueva/storefront': 24,
#  'PapaArt/cs50_project_AI': 8,
#  'pingguomaggie/open_model_zoo': 106,
#  'Patrick322/pitch': 10,
#  'hoaiphun96/Leet-Code-Problems': 111,
#  'noureddin/recite': 10,
#  'karlneco/kanji-test-maker': 29,
#  'sugatoray/colab_git_ssh': 4,
#  'jtorhoff/privacy': 124,
#  'szewski/flask-library': 4,
#  'criscola/G-Gen': 193,
#  'yayitserica/cloud-custodian': 106,
#  'ReadyNeutron/shitcoin-blockchain': 178,
#  'tekcellat/University': 193,
#  'mohitjain97/isilon_sdk_python': 17120,
#  'sei-dspooner/nlzr': 14,
#  'mstatt/multi-file-processor': 1,
#  'Buri/docker-tools': 2,
#  'kruthikarshankar/bemoss_os': 200,
#  'ChristianSch/msc-thesis': 3,
#  'tiangles/h5dj_template': 7,
#  'cjsteel/python3-venv-ansible-2.10.5': 654,
#  'ErikGro/tensorflow': 2164,
#  'HKGx/prisma-client-py': 150,
#  'blaines/integrations-core': 104,
#  'tarasov4/Intro-to-Python-Excercises': 19,
#  'NoelShin/Various-GANs': 14,
#  'kagemeka/atcoder-submissions': 5948,
#  'myhumankit/ESP32_IDE_accessible': 131,
#  'PY-GZKY/fconversion': 28,
#  'probinso/DIRE': 58,
#  'apaniukov/workbench': 470,
#  'SamyMe/django-markdown-newsletter': 18,
#  'llacb47/RunestoneServer': 12,
#  'blackPantherOS/optimus-manager': 9,
#  'burhan/gunnery': 63,
#  'RhinohawkUAV/rh_ros': 129,
#  'ryan-gunderson/mypy': 9,
#  'CampusJob/wulibs': 8,
#  'adsworth/ldp3': 22,
#  'djinnome/pybel': 228,
#  'DalyaG/dovpanda': 8,
#  'kairntech/entifyfishing-client': 28,
#  'gclm/liuli': 27,
#  'GeotrekCE/Geotrek': 717,
#  'FredericoNesti/gym-idsgame': 354,
#  'stay-whimsical/screamchess': 22,
#  'ArchieNewman/LG65-flood-warning': 35,
#  'Crissman/ray': 282,
#  'ketaro/aldryn-boilerplates': 11,
#  'ChallengedMike/100daysofcode-with-python-course': 2,
#  'yijiaozhang/hypercompare': 36,
#  'icedevil2001/PiZeroW_Plant_watering_system': 4,
#  'goubertbrent/oca-backend': 827,
#  'HsuChihwei/Hupyter': 37,
#  'aarongaut/nextsong': 29,
#  'Damon-zln/ws-scrapy': 51,
#  'bstepa/django-notify-x': 19,
#  'cmorace/pycat': 61,
#  'Scitator/ray': 61,
#  'stannum-l/schemathesis': 101,
#  'qw33ha/T-Rex_Acceleration': 32,
#  'HughPaynter/PyGRB': 38,
#  'Dudu67/home-assistant': 302,
#  'ruatm/pyFAI': 216,
#  'lu-wang-dl/joblib-spark': 6,
#  'Mivg/robust_transformers': 24,
#  'Samio-Santos/Projeto_blog_Django': 45,
#  'as1m0n/spheral': 911,
#  'ddzeko/toll-mate': 13,
#  'araffin/optuna': 24,
#  'asservio/django-asservio-core': 18,
#  'travisamacker/OldpySecurityCenter': 42,
#  'medunigraz/outpost.django.research': 20,
#  'bc-computing/rabia': 5,
#  'kuchel77/home-assistant': 1710,
#  'windfall-shogi/feature-annotation': 148,
#  'devvmh-forks/cubes': 76,
#  'sshengmin/gan_test': 88,
#  'bernikr/advent-of-code': 150,
#  'tmtaybah/bookoutlet_service': 15,
#  'cnlucas/fec-cms': 208,
#  'inventhouse/all': 2,
#  'LyndseyAdaptrum/pysnmp': 331,
#  'akshitj1/mavsim_template_files': 47,
#  'HolmesShuan/AIM2020-Real-Super-Resolution': 25,
#  'seangaringle/detectron2': 79,
#  'VRichardJP/cvat': 188,
#  'stmario/yinyang': 37,
#  'ViktorooReps/bond': 13,
#  'plourenco/indico-plugins': 69,
#  'mib1185/synologydsm-api': 17,
#  'ops-sandy/hipache': 4,
#  'anniyanvr/hydro-serving-cli': 32,
#  'tochenwei/mypython.github.io': 26,
#  'LottieWang/mindspore': 2858,
#  'o3project/odenos': 164,
#  'fennr/image-bot': 4,
#  'i4oolish/mindspore': 250,
#  'ishine/sudo_rm_rf': 3,
#  'Geal/oss-fuzz': 2,
#  'jamienoss/catkit': 27,
#  'sesam-community/freshdesk-rest': 1,
#  'SAP-samples/data-intelligence-text-analysis': 23,
#  'tvdboom/featuretools': 115,
#  'nathan-hoad/python-icap': 24,
#  'Pramothini-Sekar/boon-backend': 6,
#  'AudioVisuaali/audiobot': 86,
#  'JonnyWaffles/selenium_page': 12,
#  'mezzarobba/fungrim': 75,
#  'cyhex/tornadio2': 8,
#  'marcosviniciusbarbosa/Curso-Python': 34,
#  'haifengkao/HFTAGManager': 1,
#  'sr-vazkez/web-personal-django': 9,
#  'LHcau/scheduling-shared-passenger-and-freight-transport-on-a-fixed-infrastructure': 2159,
#  'Hanpama/wagtail': 126,
#  'sharonkorir/my-two-cents': 18,
#  'mjtice/stackstorm-jira': 21,
#  'CrystalChun/assisted-test-infra': 110,
#  'msarahan/scikit-image': 27,
#  'samlurye/fairseq': 9,
#  'metux/chromium-deb': 1657,
#  'bansan85/diptych': 19,
#  'sekanitembo/wagtail-metadata-mixin': 15,
#  'infobiac/stanza': 66,
#  'patras91/rae_release': 1479,
#  'hippalectryon-0/apollo': 62,
#  'nbobrov8/Laba4': 4,
#  'benSepanski/loopy': 73,
#  'neverlosecc/api-wrapper': 23,
#  'LM095/Multi-Subtask-DRL-for-Pick-and-Place-Task': 31,
#  'stevenkbennett/stk': 791,
#  'tupipa/beri': 853,
#  'nmgeek/gridpath': 472,
#  'karol-brejna-i/openfl': 129,
#  'DaveBerkeley/litex-boards': 108,
#  'ShaneShen/MutualNet': 7,
#  'shaido987/pyaf': 8775,
#  'EiffL/hierarchical-dnn-interpretations': 19,
#  'romaninsh/botostubs': 6,
#  'liggest/RGBDFace': 18,
#  '0xdea/tactical-exploitation': 1,
#  'danrs/r2-d7': 9,
#  'kulado/kulado-azure': 396,
#  'johnkennyuk/supervisor': 14,
#  'SAP-samples/security-research-fed-dp-mia': 37,
#  'gauravkumarpandey/python': 14,
#  'yennanliu/CS_basics': 305,
#  'latenite4/python3': 22,
#  'RlyehAD/mmic_optim_gmx_old': 13,
#  'graphsense/graphsense-tagpack-tool': 6,
#  'myselfajp/MyFirstPage': 44,
#  'Muzque/Leetcode': 206,
#  'lucifurtun/myquotes': 42,
#  'ismacaulay/qtcwatchdog': 20,
#  'Xanonymous-GitHub/data-structure': 13,
#  'mevtorres/pvextractor': 24,
#  'Dr8Ninja/ShareSpace': 151,
#  'raymondyegon/awards': 43,
#  'Shashankjain12/arviz': 5,
#  'nilskk/models': 33,
#  'hyperonecom/h1-client-python': 783,
#  'hunyadi/pylinsql': 21,
#  'pswietojanski/pyroomacoustics': 24,
#  'jsebastianms1/kinto': 164,
#  'aaaaadamchen/tensorflow': 918,
#  'abeeraleisa/ignite': 253,
#  'Cyprella/brofist': 22,
#  'syeo/tf_mesh_renderer': 6,
#  'uoguelph-mlrg/LDG': 9,
#  'blogle/tensorpack': 133,
#  'caiyongji/tf2.3.1-py3.7.9-full-built': 2609,
#  'Mischback/django-calingen': 72,
#  'nsxsnx/py-tgbot-twitter-timeline': 2,
#  'menntamalastofnun/txtemplate': 9,
#  'drajen/nimble-python-sdk': 52,
#  'rtl68k/basil': 110,
#  'SeanAmmirati/deep-lyric-visualizer': 21,
#  'NCTUMLlab/Je-Wei-Jang-AVAST_Attentive_Variational_State_Tracker_for_Vision-and-Language-Navigation': 29,
#  'Loodos/zemberek-python': 74,
#  'trallard/pycon2020-azure-functions': 9,
#  'geo-knowledge-hub/invenio-rdm-records': 204,
#  'Kenneth-T-Moore/OpenMDAO-Framework': 211,
#  'lyt217/lissomcoin-core': 6,
#  'jvegasbsc/ESMValCore': 149,
#  'awlauria/ompi-scripts': 15,
#  'easonwhite928/DSNTSP': 21,
#  'Highjhacker/PytharkFlask': 6,
#  'akmcinto/TodoApp': 34,
#  'johnbartholomew/bookwyrm': 111,
#  'SartMorgs/arm-compiler': 13,
#  'pjquirk/azure-sdk-for-python': 675,
#  'matt2000/confluent-kafka-python': 19,
#  'antopen/alipay-sdk-python-all': 10290,
#  'feluelle/great_expectations': 173,
#  'MPSLab-ASU/dMazeRunner': 34,
#  'prusse-martin/conda-devenv': 10,
#  'Eyepea/python-phonenumbers': 381,
#  'GLZ1925/TechServerKG': 2,
#  'enthought/etsproxy': 2187,
#  'OpenISA/riscv-sbt': 19,
#  'amalchuk/readable': 48,
#  'UCLA-SEAL/QDiff': 33007,
#  'meliao/ukbrest': 30,
#  'roadnarrows-robotics/elemenpy': 47,
#  'AndreaVoltan/MyKratos7.0': 908,
#  'bibxpert/bibxpert': 14,
#  'NyoNyoHtwe/Python-exercises': 47,
#  'Timost/dask': 117,
#  'paryoja/finance-api': 37,
#  'yipstar/surf_python': 25,
#  'hmcts/nginx-role': 2,
#  'MikeKnowles/parallel_itsx': 5,
#  'mesmerlord/imdb_scrape': 34,
#  'mkazin/StatementRenamer': 41,
#  'dting/staketaxcsv': 65,
#  'Antash696/simpalgs': 16,
#  'raphaelreme/bomberman': 29,
#  'ayush9000/kaistusc': 86,
#  'neermitt/mibs.snmplabs.com': 20871,
#  'dgehringer/pyiron_atomistics': 157,
#  'AlenaYanish/Data_converter': 154,
#  'JamzumSum/IndexSerializer': 3,
#  'zconnect-iot/zconnect-django': 145,
#  'Archaic-Atom/JackFramework': 37,
#  'andrisecker/KOKI_sharp_waves': 23,
#  'Autumnn/DESlib': 66,
#  'maxcohen31/A-bored-math-student': 181,
#  'kolibril13/napari': 147,
#  'tdkhanhvu/VoiceScraping': 7,
#  'sondree/b2_fuse': 10,
#  'rankrh/soli': 124,
#  'hroncok/lesscpy': 22,
#  'dantswain/heavy_meta': 19,
#  'H-BlackGom/StockDataCrawler-Python': 6,
#  'IuliuNovac/mmswin': 575,
#  'sgfCrazy/detectron2_old': 13,
#  'jhutchings1/autogluon': 21,
#  'sanjana87/catapult': 816,
#  'NoNotCar/pycollo': 70,
#  'spiritus72/oppia': 192,
#  'marcottelab/Slicem': 2,
#  'MaksymDubchak/BingAds-Python-SDK': 212,
#  'hset911/openvino': 1356,
#  'JeremyARussell/Lucida': 5,
#  'tr3ck3r/linklight': 2037,
#  'MarcosLazarin/Meu-curso-em-v-deo': 114,
#  'hyunobae/SRGAN': 9,
#  'VaChristiaens/VIP': 45,
#  'slieberth/ixnetwork_restpy': 2575,
#  'TRex22/picamerax': 79,
#  'marqeta/marqeta-python': 439,
#  'SaggingRufus/sahasrahbot': 58,
#  'ankitarorabit/azure-sdk-for-python': 259,
#  'FilippoPisello/Books-Read-DB': 13,
#  'shihchengli/RMG-Py': 439,
#  'datalogics/circulation': 88,
#  'nspcc-dev/neo-python': 196,
#  'EnjoyLifeFund/py36pkgs': 12056,
#  'zhangzhang-1/assistive-gym': 63,
#  'gbalke/rclpy': 9,
#  'matherm/ummon3': 118,
#  'deepakavattotte2191/FISBO-Real-esate--website': 24,
#  'TomVasile/CasperLabs': 29,
#  'lpython2006e/exercies': 178,
#  'miguelsndc/Exercicios-Python': 143,
#  'davmre/sigvisa': 325,
#  'Azure/autorest.python': 846,
#  'SunChuquin/pyqode.core': 65,
#  'maxzhenzhera/my_vocab_backend': 194,
#  'Scalr/kubernetes-client-python': 1255,
#  'retrieva/fastseq': 46,
#  'ministryofjustice/sentencing-guidelines-api-prototype': 14,
#  'rjw57/bitsbox': 18,
#  'BarnabyShearer/aoc': 170,
#  'latedude2/P3_image_processing': 62,
#  'codlin/dashboard': 23,
#  'r4ulill0/gui_dbjudge': 55,
#  'dsplugins/dc-app-performance-toolkit': 33,
#  'Lidia1Santos/Exercicios': 6,
#  'astromaddie/pywavelets-py3': 37,
#  'RomanYarovoi/oms_cms': 201,
#  'Xiaojieqiu/pysmFISH': 14,
#  'mtanji/intro-algorithm-python': 33,
#  'LeafyLappa/starlette-jsonapi': 42,
#  'AZMAG/urbansim_templates': 30,
#  'zacwang89/global-indicators': 6,
#  'KoyanagiHitoshi/AtCoder': 1330,
#  'eldstal/CTF': 26,
#  'jayachithra/azure-sdk-for-python': 18192,
#  'wuye999/pyportable-installer': 62,
#  'SparksFly8/DataMingingPaper': 34,
#  'ksheedlo/quickplot': 3,
#  'pycroscopy/sidpy': 10,
#  'ElliotCheung/simpeg': 203,
#  'sertraline/Chizuhoru': 10,
#  'Bl00per72/taichi': 7,
#  'ridv/aurora': 232,
#  'SarthakSingh31/django-webpack-bridge': 18,
#  'bkiers/python3-parser': 32,
#  'teo-milea/federated': 213,
#  'grindhold/pysaml2': 15,
#  'bdbaddog/scons': 6,
#  'AM2i9/wpilib-ws-py': 6,
#  'sebalander/sebaPhD': 60,
#  'NateLehman/azure-sdk-for-python': 1890,
#  'JohannesIBK/plyoox-bot': 37,
#  'neuronalX/reservoirpy': 39,
#  'juanchodepisa/sbtk': 53,
#  'datasheppard/Unit-3-Sprint-3': 2,
#  'blueyed/pythonfinder': 17,
#  'profrafaeldan/ccxt': 306,
#  'zhangxiangxiao/Glyph': 16,
#  'jamvar/azure-linux-extensions': 18,
#  'software-foundations/learning-python': 28,
#  '1103928458/meiduo_drf': 58,
#  'erdosnumber0/plotly.py': 9423,
#  'anliven/L-Python': 290,
#  'noooway/exj': 26,
#  'spradeepv/dive-into-python': 256,
#  'shaftoe/sslnotifyme': 8,
#  'ashari4/pytorch-1': 61,
#  'drsantos89/sp500sim': 5,
#  'googleinterns/vm-network-migration': 69,
#  'PriyankaH21/astropy': 243,
#  'albertozurli/mammoth': 42,
#  'jalauzon-msft/azure-sdk-for-python': 2056,
#  'rmdes/tanzawa': 186,
#  'Tianhao-Y/Automatic-Control-System-for-Heat-Pump': 6,
#  'GEOS-ESM/GMAO_Shared': 132,
#  'eisenefaust/hackathong2021': 6,
#  'ComFreight/cmft-stripe-integration': 59,
#  'noriyukipy/smilechat': 21,
#  'UrbanDaddy/django-cloud-browser': 8,
#  'zilishen/gala': 124,
#  'xuehw357/mediasoup': 453,
#  'edublancas/pkgmt': 18,
#  'hust-wuwechao/mxnetv2': 319,
#  'Requirement-Engineers/default-coding-Bo2': 11,
#  'usegalaxy-no/usegalaxy': 5103,
#  'tomix1024/electrum': 4,
#  'sandeepm96/cormen-algos': 52,
#  'Friedenspanzer/budgeteer': 11,
#  'RoCice/train': 6343,
#  'docharlow/spoomy': 77,
#  'GeorgePanzerMathew/DISCAW': 21,
#  'ikejs/SPD-2.31-Testing-and-Architecture': 23,
#  'matejdro/libpebble2': 52,
#  'iamdanialkamali/coup_bot': 5,
#  'go2starr/lshhdc': 7,
#  'wudizhangzhi/Gerapy': 51,
#  'ml1944190/code': 4466,
#  'cmbruns/vr_samples': 12,
#  'ieso/label-studio': 4,
#  'qwhelan/xarray': 13,
#  'CrysTalesiaS/Bot': 81,
#  'hth945/pytest': 1413,
#  'marloncortez/cloud-forensics-utils': 22,
#  'steven-lang/e2cnn': 113,
#  'NullConvergence/torch_temp': 88,
#  'arraynetworks/array-lbaasv2-driver': 9,
#  'IsaacMurage-dev/The-hood': 9,
#  'itaru2622/aries-cloudagent-python': 340,
#  'iskandr/mhcnames': 19,
#  'GuSilva20/Primeiros-Codigos': 50,
#  'killstrelok/insightconnect-plugins': 5594,
#  'fernandoleira/stocktext': 365,
#  'yashgoyal2802/TimeTable-Generation': 4,
#  'sgoel97/Magnetism-Calculations': 5,
#  'amado-developer/ReadHub-RestfulAPI': 456,
#  'MostafaSamyFayez/E-Commerce-Sys': 41,
#  'nmaekawa/mediamanager': 47,
#  'rashidulhasanhridoy/URI-Online-Judge-Problem-Solve-with-Python-3': 174,
#  'fazildgr8/realsense_explorer_bot': 5,
#  'jkabalar/kapture-localization': 60,
#  'shiniao/nest': 7,
#  'aachurin/broccoli': 19,
#  'mjuenema/python-terrascript': 1955,
#  'mgaligniana/django': 1451,
#  'roshankaanthmks/JobSalaryPrediction': 4,
#  'Nitinsd96/Air-Pollution-Monitoring-System': 117,
#  'NVIDIA/ais-tar2tf': 3,
#  'zhuzhenping/XAPI3': 30,
#  'Algorithmic-Alignment-Lab/openTAMP': 257,
#  'hoohacks/HackX': 71,
#  'PSwitty/dagster': 1960,
#  'JackLi529/FATE': 983,
#  'Lambda-School-Labs/human-rights-first-d-ds': 10,
#  'renovate-bot/python-irm': 12,
#  'strike-afk/strike-tools': 1,
#  'ppwadhwa/holoviews': 302,
#  'swansonk14/multiobj-rationale': 24,
#  'deagwon97/django-react-template': 18,
#  'riaz-bordie-cko/checkout-sdk-python': 155,
#  'herculan0/server-monitoring': 1,
#  'marchon/Flask-Simple-Registration': 2,
#  'Rokiaa/recipe-app-API': 6,
#  'aldebaran1/pyTID': 28,
#  'withthelemons/lemoncoin': 5,
#  'ahus1/pretix': 149,
#  'Nektar97/Restaurant': 1,
#  'jejjohnson/survae_flows_lib': 23,
#  'ahasan20/georgsmusic': 6,
#  'chris-sanders/cdk-scripts': 28,
#  'chiplet/apicula': 9,
#  'fritzo/pomagma': 120,
#  'jojurajan/jaraco.postgres': 4,
#  'jasonx1011/densecap-tensorflow': 52,
#  'blockchain-development-resources/bxgateway': 171,
#  'hotchilianalytics/zipline-broker': 42,
#  'shotarok/kfserving': 25,
#  'bhattbhuwan13/zenml': 150,
#  'brycelelbach/nt2': 1012,
#  'Deego-Robotics/SimpleFOCStudio-zh': 17,
#  'mayronceccon/olist-python-labs-project': 27,
#  'hanqf-git/ClickHouse': 3,
#  'bmwcarit/joynr': 6,
#  'jbuoncri1/OpenMetadata': 70,
#  'ckdrjs96/KoBart': 4,
#  'felixwege/agents': 269,
#  'tardyp/pypugjs': 2,
#  'dani-han/koapy': 116,
#  'NikithaKrish/PaddleNLP': 42,
#  'chisholm/cti-taxii-client': 4,
#  'flyonok/DeepStack': 514,
#  'kalagasp/JetPack': 69,
#  'sdimartino510/curriculum-runthrough': 35,
#  'Anand911/LIVE-CRICKET-SCOREBOARD': 9,
#  'HumanResourceMachine/hrm': 16,
#  'googleapis/googleapis-gen': 8417,
#  'adrianomqsmts/OneFigure-gRPC': 18,
#  'hal2001/pandas': 41,
#  'ikiril01/cti-sep-repository': 1,
#  'lhztop/python-rocksdb': 3,
#  'marching-cube/python-mysql-replication': 18,
#  'Switch-Mexico/switch-inputs': 16,
#  'lfzarazuaa/LiderSeguidorA': 44,
#  'Stefan-Code/gglsbl3': 17,
#  'NaN-xyz/Glyphs-Scripts': 136,
#  'awslabs/syne-tune': 295,
#  'gleighto/rapmedusa': 8,
#  'ljzhang123/cgi-lab': 3,
#  'ansabgillani/binarysearchcomproblems': 521,
#  'a1600012888/mmdetection3d': 152,
#  'thelucyclub/meme-server': 86,
#  'sintel-dev/SigPro': 35,
#  'go-choppy/choppy-report': 29,
#  'pune-lug/DeepVideoAnalytics': 102,
#  'LavanyaRamkumar/Selfiless-acts': 10,
#  'ai-snow/qrandom': 5,
#  'CR1AT0RS/djangosaml2': 24,
#  'digantdesai/pytorch': 108,
#  'Logonz/wowhead_scraper': 19,
#  'meijing0114/redis-in-action-implementation': 12,
#  'IAmigos/imaginaire': 147,
#  'nonamescientist/NCAE_UAD': 10,
#  'scality/ghaudit': 25,
#  'ServiusHack/core': 115,
#  'dmjoy/Danesfield': 96,
#  'lin826/pfrl': 54,
#  'RicardoVinicioJara/LugaresTusisticos': 158,
#  'hixio-mh/luci-py': 111,
#  'mrphys/keras-declarative': 17,
#  'tjwalch/plata': 50,
#  'Spartronics4915/2016-Stronghold': 22,
#  'dragonfly-science/django-extensions': 17,
#  'PCManticore/python-future': 146,
#  'championway/asv_ros': 29,
#  'MichaelZhero/Paddle': 128,
#  'rchile/modlog-api': 5,
#  'AaronFriel/pulumi-google-native': 2637,
#  'Tobias-Fischer/ros_people_object_detection_tensorflow': 183,
#  'trietnguyenjhu/datsup': 11,
#  'c834606877/llvm-project': 100,
#  'tch/river': 311,
#  'Chaojidahoufeng/SGroup_RL': 368,
#  'cmattey/leetcode_problems': 309,
#  'nate-axonius/content': 625,
#  'WangFeng18/InvariancePropagation': 37,
#  'mhturner/SC-FC': 13,
#  'its-sushant/coding-interview-gym': 369,
#  'peteraw77/linguistic-analysis': 5,
#  '0t1s1/spack': 1020,
#  'armanrahman22/anago': 22,
#  'chargio/using-koku-api-test': 219,
#  'kangtastic/cryptopals': 61,
#  'chae-heechan/Algorithm_Study': 115,
#  'rachmadaniHaryono/Pixiv': 5,
#  'nolanzzz/mtmct': 75,
#  'KoyanagiHitoshi/AtCoder-Python-Introduction': 425,
#  'Soum-Soum/Tensorflow_Face_Finder': 995,
#  'Boukefalos/pylibibuddy': 8,
#  'Khan/gae_bingo': 10,
#  'rwst/sympy': 62,
#  'HASSAN1A/my_users_api': 10,
#  'dpticar/meerk40t': 89,
#  'paurosello/frappe': 33,
#  'xmrio/ccxt': 84,
#  'Titousensei/pytext-1': 103,
#  'decaun/easy-python-study': 157,
#  'liyier90/PeekingDuck': 226,
#  'wohlbier/ogb': 9,
#  'maccinza/django-mssql-backend': 2,
#  'tallamjr/AIrsenal': 36,
#  'AhernEYeldarB/PublicTransportRoutemap': 13,
#  'EVBiotechBV/biosteam': 71,
#  'YarShev/daal4py': 44,
#  'chaostoolkit/chaosplatform-account': 42,
#  'michiboo/gluon-ts': 78,
#  'xyupeng/ContrastiveCrop': 58,
#  'animesh/parliament2': 2064,
#  'mvdwerve/price-representation-research': 31,
#  'franblas/pyAPI': 32,
#  'gaozhengwei/networking-ovn': 91,
#  'kdmsit/myutil': 11,
#  'phcooper/azure-cli': 101,
#  'joniok/hybra-medialoader': 109,
#  'chungus-ii/eCybermission': 12,
#  'hughesm1/20-Exam3Practice': 7,
#  'zhupangithub/WEBERP': 677,
#  'LorranSutter/URI-Online-Judge': 335,
#  'RheingoldRiver/misc-cogs': 47,
#  'Sipondo/ulix-dexflow': 267,
#  'SamuelMarks/flax': 164,
#  'Fanxingye/AutoDL': 148,
#  'RomelioTavas/Speech-Recognition-ANN': 6,
#  'qianhk/FeiPython': 202,
#  'lorenzomammana/numpy': 1,
#  'Samad999777/tensorflow-recorder': 13,
#  '4lrz/ml-newbie': 22,
#  'alemangui/APIv3-python-library': 79,
#  'Jakgn/gem5_test': 286,
#  'dymaxionlabs/eo-learn-stac': 8,
#  'gauravssnl/cachecontrol': 14,
#  'jhson989/jhML': 49,
#  'plusus/plus-tuto': 42,
#  'chop2/MobulaOP': 38,
#  'darijgr/sage': 493,
#  'yanyuchka/tfx': 21,
#  'Brain-Flooder/YAIS': 8,
#  'debashriroy/DeePOE': 19,
#  'SRainot/gadgetBot': 27,
#  'DavideDC9/numerous': 25,
#  'Aristo-eng/Data-analysis-with-python-2022': 41,
#  'stevenshuang/Homeworks': 8,
#  'sdnit-se/intersight-python': 4820,
#  'bdfd/Python_Zero2Hero_DS': 121,
#  'vtta2008/pipelineTool': 311,
#  'Meatlf/OpenCV4': 1,
#  'XuyangBai/DeepGlobalRegistration': 6,
#  'cloudmatrix/esky': 29,
#  'AyrtonB/dagster': 364,
#  'anjomro/django-tastypie-swagger': 6,
#  'Umiiii/chiadog': 53,
#  'GOODBOY008/kafka': 26,
#  'CFarcy/baserow': 515,
#  'limenghao/incubator-tvm': 1235,
#  'dignajar/log4j-tools': 2,
#  'lvclark/h3agwas': 15,
#  'moshthepitt/answers': 73,
#  'ishine/cotk': 75,
#  'paulgavrikov/adversarial_robustness_pytorch': 41,
#  'zagm/resolwe': 223,
#  'dantownsend/xpresso': 160,
#  'bmerry/pyopencl': 42,
#  'mohansd/cyx-xElec-server': 95,
#  'crowdbotics-apps/app-1-33544': 5,
#  'ChyiYaqing/chyidlTutorial': 217,
#  'y1j2x34/checkov': 1407,
#  'Cloudmersive/Cloudmersive.APIClient.Python.Convert': 564,
#  'simonguichandut/curvefitting': 8,
#  'jamestszhim/adaptive_augment': 11,
#  'Melancias/ad_projecto4': 5,
#  'Jianwei-Wang/python2.7_lib': 458,
#  'gitter-lab/prmf': 69,
#  'aistairc/market-reporter': 35,
#  'genegr/py-pure-client': 6889,
#  'smurawski/azure-cli-extensions': 47,
#  'taigaio/taiga-ncurses': 43,
#  'ac427/sysdig-sdk-python': 104,
#  'sega-hsj/Video_Feature': 380,
#  'jgmize/kitsune': 207,
#  'dunno99/intellij-community': 7877,
#  'rpoluri/hue': 908,
#  'tsingcbx99/Transfer-Learning-Library': 211,
#  'AbhiiGatty/adversarial-robustness-toolbox': 43,
#  'WWU-AMM/ontology-visualization': 13,
#  'liushuya7/lbriiwa': 10,
#  'jamesp-epcc/rucio': 220,
#  'kophjager007/mitmproxy': 65,
#  'fghaas/openstack-magnum': 223,
#  'MorriganR/SciPyFST': 16,
#  'david-zwicker/sensing': 44,
#  'Jay4C/Python-Macros-For_FreeCAD': 267,
#  'Harry-Verspagen/2is50-2019-2020-homework-assignment-1-pair-50': 5,
#  'RamanLab/iCOMIC': 15,
#  'pulumi/pulumi-kubernetes-crds': 944,
#  'tangh/mmaction2': 18,
#  'namelivia/travelperk-http-python': 94,
#  'sweettea/pytorch': 43,
#  'igorlimansky/aio-pika': 13,
#  'gowthamk63/django': 7,
#  'hut-b7/europarl-uds': 11,
#  'RomanSmolka/script.handover': 4,
#  'deandunbar/html2bwml': 40,
#  'tucanae47/redpitaya_migen': 5,
#  'parkerashlan/pandas': 319,
#  'jbradberry/django-postoffice': 13,
#  'david-cortes/xgboost': 14,
#  'verdimrc/gluon-ts': 30,
#  '4bdu1/fastapi-sqlmodel-demo': 7,
#  'giovanniherdigein/my_first_django': 7,
#  'JJJollyjim/faucet': 74,
#  'momyc/pybrake': 11,
#  'huamichaelchen/azure-sdk-for-python': 8562,
#  'kontais/EFI-MIPS': 83,
#  'guardicore/nitro-python': 1597,
#  'znes/angus-scenarios': 21,
#  'earl86/vitess': 126,
#  'Busaka/excellence': 118,
#  'HammerMeetNail/quay': 194,
#  'dimastark/pyndler': 13,
#  'Binx-Codes/neorg-discord-bot': 5,
#  'skydengyao/sssegmentation': 347,
#  'zzj403/yolo4_dap': 14,
#  'msandstedt/connectedhomeip': 34,
#  'mrsempress/mmdetection': 1483,
#  'liumihust/aliyun-openapi-python-sdk': 3830,
#  'ardavast/AdventOfCode': 44,
#  'elisong/pycmd': 13,
#  'fwu11/tf_estimator_barebone': 12,
#  'dapengchen123/code_v1': 21,
#  'jeremiedecock/snippets': 907,
#  'EremeevVV/Multi-Type-TD-TSR': 19,
#  'ZeusWPI/Blokdata': 5,
#  'MaxNoe/sklearn-onnx': 67,
#  'k20human/domoticz-atome': 3,
#  'kiranajij/manim': 182,
#  'keithCollins77093/hardInfo': 19,
#  'choderalab/rumm': 24,
#  'litinkumar/attendence-app': 11,
#  'KenMercusLai/checkio': 218,
#  'masterfabela/practicas-pyton': 35,
#  '5267/QUANTAXIS': 78,
#  'ImmaculateObsession/nest': 48,
#  'khanfluence/stacki-cumulus-switch': 545,
#  'xiong-jie-y/pika': 38,
#  'Wayne-Dreyer/High-Cadence-Processing': 62,
#  'einsfr/wagtailmodelchooser': 4,
#  '627oldcat/CNN_virus': 13,
#  'KostiantynYarovyiBf/sonic-mgmt': 539,
#  'ugosan/eland': 112,
#  'marlenebDC/pycon': 293,
#  'fpvmorais/pyapacheatlas': 1,
#  'UKPLab/emnlp2018-argmin-commonsense-knowledge': 15,
#  'burgerkingeater/io': 17,
#  'j-pedrofag/SEII-JoaoPedroSilvaFagundes': 29,
#  'yzainee/fabric8-analytics-jobs': 63,
#  'wikimedia/labs-tools-wikibugs2': 24,
#  'jtslade/satchmo-svn': 225,
#  'KishManani/statsmodels': 493,
#  'AaronFriel/pulumi-onelogin': 19,
#  'DiscordDigital/ui.py': 1,
#  'cod3gen/ccxt': 48,
#  'nbl97/nni': 66,
#  'gar-syn/octopus': 53,
#  'Vjrx/airship-drydock': 201,
#  'f3d0r/aspace-sensor': 10,
#  'tdiggelm/datasets': 38,
#  '0x4e3/filertools': 24,
#  'fancyicookie/HDRUNet': 21,
#  'munkm/yt': 669,
#  'numba/roc-examples': 17,
#  'digipodium/market-basket-analysis': 14,
#  'ytyaru/BeautifulSoup.SelectLeafNode.201705150722': 2,
#  'kulawczukmarcin/mypox': 24,
#  'is-pyu/openNAMU': 108,
#  'megvii-research/Iter-E2EDET': 44,
#  'tlambert03/pyOMElite': 20,
#  'kinghuang/sentry': 1148,
#  'Posedge/zackig': 10,
#  'mazerius/khronos': 20,
#  'nicolaiarocci/Eve.NET-testbed': 8,
#  'Sk0uF/Algorithms': 149,
#  'jashandeep-sohi/astrometry.net': 90,
#  'roverdotcom/django-geo': 13,
#  'longhoangwkm/counterparty-lib': 64,
#  'wware/zipline': 98,
#  'ericleb010/chrome-automated-device-mode': 2,
#  'BlueLens/bl-db-index': 11,
#  'paulondc/chilopoda': 217,
#  'elonzh/hfut': 20,
#  'KuroLight/Billboard-Trends': 3,
#  'SolidStateGroup/Bullet-Train-API': 186,
#  'jreback/ibis': 188,
#  'seblee97/dqn_zoo': 17,
#  'Unnikuttankk/Unlimited-Filter-Bot': 9,
#  'YongJin-Cho/poseidonos': 178,
#  'DongriPocket/study': 11,
#  'myNet09/GRPC1': 53,
#  'seunomonije/quantum-programming-api': 23,
#  'tychoish/mongo': 22,
#  'neutronimaging/circular_profiler': 10,
#  'Superalvin1123/wcs-python3-sdk': 21,
#  'NBU-CSCB532/emotional_valence': 31,
#  'anirudhacharya/sagemaker-debugger': 22,
#  'ChaonengTan/ACS-4931-Testing-and-Architecture': 6,
#  'ctgk/bayes': 119,
#  'sth4nothing/pyleetcode': 134,
#  ...}

# %%
repo_info=pd.DataFrame.from_dict(x,columns=['repo_name','scripts_num'],orient='index')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 repo_info=pd.DataFrame.from_dict(x,columns=['repo_name','scripts_num'],orient='index')
#
# File ~/miniforge3/envs/twmc/lib/python3.9/site-packages/pandas/core/frame.py:1760, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1754     raise ValueError(
#    1755         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1756         f"Got '{orient}' instead"
#    1757     )
#    1759 if orient != "tight":
# -> 1760     return cls(data, index=index, columns=columns, dtype=dtype)
#    1761 else:
#    1762     realdata = data["data"]
#
# File ~/miniforge3/envs/twmc/lib/python3.9/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
#     802             dtype=dtype,
#     803             copy=copy,
#     804             typ=manager,
#     805         )
#     806 else:
#     807     mgr = dict_to_mgr(
#     808         {},
#     809         index,
#    (...)
#     812         typ=manager,
#     813     )
#
# File ~/miniforge3/envs/twmc/lib/python3.9/site-packages/pandas/core/internals/construction.py:337, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     332 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     333 index, columns = _get_axes(
#     334     values.shape[0], values.shape[1], index=index, columns=columns
#     335 )
# --> 337 _check_values_indices_shape_match(values, index, columns)
#     339 if typ == "array":
#     340     if issubclass(values.dtype.type, str):
#
# File ~/miniforge3/envs/twmc/lib/python3.9/site-packages/pandas/core/internals/construction.py:408, in _check_values_indices_shape_match(values, index, columns)
#     406 passed = values.shape
#     407 implied = (len(index), len(columns))
# --> 408 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (2030000, 1), indices imply (2030000, 2)

# %%
new_dict={'repo_name':[],'scripts_num':[]}
for key,value in x.items():
    new_dict['repo_name'].append(key)
    new_dict['scripts_num'].append(value)

# %%
repo_info=pd.DataFrame.from_dict(new_dict)

# %%
repo_info_more_than_10_less_than_50=repo_info[(repo_info['scripts_num']>=10) & (repo_info['scripts_num']<=50)]

# %%
repo_info_more_than_10_less_than_50
# Out:
#                                             repo_name  scripts_num
# 3        wjones30309/MachineLearningSamples-Notebooks           10
# 10                                     bglobal/origin           15
# 13                   sgibson91/bump-jhub-image-action           13
# 14                                  ace19-dev/CBNetV2           22
# 17                       escer/django-multivaluefield           10
# ...                                               ...          ...
# 1758654                               malcolmt/django           10
# 1772251                 Linamiao-1998/facenet-pytorch           11
# 1799505                               happybits/napfs           11
# 1811998                                milliams/proof           11
# 1817435                               KyleLan329/blog           10
#
# [422984 rows x 2 columns]

# %%
repo_info_more_than_10_less_than_50.to_csv('repo_info_more_than_10_less_than_50.csv')

# %%
repo_info
# Out:
# Empty DataFrame
# Columns: [repo_name, scripts_num]
# Index: []
